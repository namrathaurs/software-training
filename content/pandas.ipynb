# %% [markdown]
# # **Pandas**
#
# ![pandas_logo.png](attachment:59c6416f-b847-472a-9a04-e2e0e09585df.png)

# %% [markdown]
# Pandas allows scientists and engineers to work efficiently with tabular data. It provides spreadsheet-like capabilities, powerful filtering, and rapid statistical analysis directly in Python.

# %% [markdown]
# ## **Dataframe**

# %% [markdown]
# A dataframe is essentially a table where data is organized into rows and columns. The rows represent observations and columns represent variables.

# %%
import pandas as pd

data = {
    "Sensor": ["A", "B", "C", "D"],
    "Temperature": [21.3, 22.5, 20.8, 23.1],
    "Pressure": [101.2, 100.9, 101.5, 101.0]
}

df = pd.DataFrame(data)

# %% [markdown]
# ## **Inspecting Data**

# %%
# inspect the top few rows of your data
# by default, returns the first 5 rows of your data

# %%
# inspect the variables for your data

# %%
# understand how many observations and variables are in your data

# %% [markdown]
# ## **Selecting Columns**
#
# You can analyze the data based on variables of interest.

# %%
# selecting one column...

# %%
# selecting multiple columns...

# %% [markdown]
# ## **Filtering Data**

# %%
# filter observations where temperature is above 22 Celsius

# %% [markdown]
# ## **Quick Statistics**

# %%
# finding the average temperature...

# %%
# finding the maximum temperature...

# %%
# finding the minimum temperature...

# %%
# calculating the standard deviation for temperature...

# %%
# alternatively, summarize everything...

# %% [markdown]
# ## **Sorting Data**
#
# If you want to identify the hottest temperatures in your data, you can sort your data.

# %%
# by default, sorts in ascending order

# %%
# to sort in descending order

# %% [markdown]
# ## **Creating New Columns**

# %%
import pandas as pd

df = pd.DataFrame({
    "EventID": [1, 2, 3, 4],
    "Energy_GeV": [12.5, 18.3, 7.9, 22.1]
})

# %%
# create a new column that converts MeV energy to GeV

# %% [markdown]
# ## **Quick Exercise**
#
# Given the following dataframe:

# %%
import pandas as pd

df = pd.DataFrame({
    "Sample": ["A", "B", "C", "D", "E"],
    "Value": [12, 8, 15, 22, 10]
})

# %% [markdown]
# 1. Display the dataframe.

# %%
# Your code goes here

# %% [markdown]
# 2. Compute the mean value.

# %%
# Your code goes here

# %% [markdown]
# 3. Find the maximum value.

# %%
# Your code goes here

# %% [markdown]
# 4. Select rows where Value > 10.

# %%
# Your code goes here

# %% [markdown]
# 5. Count how many rows satisfy Value > 10.

# %%
# Your code goes here

# %% [markdown]
# ## **[Take-Home] Self-Exploration**

# %% [markdown]
# :::{tip}
# Using Google Search will be extremely valuable when you are doing the self-exploration.
# :::

# %% [markdown]
# * Working with CSV files
# * Handling missing data
#    * identification of missing values
#    * counting missing values
#    * removing missing rows
#    * replacing missing values
# * Grouping data
# * Combining conditions
